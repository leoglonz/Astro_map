# %%
import numpy as np
import pylab
import pynbody
import pynbody.plot.sph as sph
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd

from astropy import units
from astropy import constants as c

import warnings
warnings.filterwarnings("ignore")

# from analysis import *

# %%
def read_tracked_particles(sim, haloid, verbose=False):
    
    if verbose: print(f'Loading tracked particles for {sim}-{haloid}...')
    
    key = f'{sim}_{str(int(haloid))}'

    # import the tracked particles dataset
    path1 = '/home/lonzaric/astro_research/Stellar_Feedback_Code/SNeData/tracked_particles_v2.hdf5'
    data = pd.read_hdf(path1, key=key)
    
    time = np.unique(data.time)
    dt = time[1:]-time[:-1]
    dt = np.append(dt[0], dt)
    dt = dt[np.unique(data.time, return_inverse=True)[1]]
    data['dt'] = dt
    
    
    if verbose: print('Successfully loaded')
    
    r_gal = np.array([])
    for t in np.unique(data.time):
        d = data[data.time==t]
        r_gas = np.mean(d.sat_r_gas)
        r_half = np.mean(d.sat_r_half)
        rg = np.max([r_gas,r_half])

        if np.isnan(rg):
            rg = r_gal_prev

        if verbose: print(f't = {t:1f} Gyr, satellite R_gal = {rg:.2f} kpc')
        r_gal = np.append(r_gal,[rg]*len(d))

        r_gal_prev = rg

    data['r_gal'] = r_gal
    
    r_gal_prev = 0
    r_gal = np.array([])
    for t in np.unique(data.time):
        d = data[data.time==t]
        r_gas = np.mean(d.host_r_gas)
        r_half = np.mean(d.host_r_half)
        rg = np.max([r_gas,r_half])

        if np.isnan(rg):
            rg = r_gal_prev

        if verbose: print(f't = {t:1f} Gyr, host R_gal = {rg:.2f} kpc')
        r_gal = np.append(r_gal,[rg]*len(d))

        r_gal_prev = rg

    data['host_r_gal'] = r_gal
    
    thermo_disk = (np.array(data.temp) < 1.2e4) & (np.array(data.rho) > 0.1)
    
    in_sat = np.array(data.in_sat)
    other_sat = np.array(data.in_other_sat)
    in_host = np.array(data.in_host) & ~in_sat & ~other_sat
    
    sat_disk = in_sat & thermo_disk
    sat_halo = in_sat & ~thermo_disk
    
    host_disk = in_host & thermo_disk
    host_halo = in_host & ~thermo_disk
    
    IGM = np.array(data.in_IGM)
    
    # basic location classifications.
    data['sat_disk'] = sat_disk
    data['sat_halo'] = sat_halo
    data['host_disk'] = host_disk
    data['host_halo'] = host_halo
    data['other_sat'] = other_sat
    data['IGM'] = IGM

    return data

# %%
key = 'h148_13'

path = '/home/lonzaric/astro_research/Stellar_Feedback_Code/SNeData/discharged_particles.hdf5'
discharged = pd.read_hdf(path, key=key)

path = '/home/lonzaric/astro_research/Stellar_Feedback_Code/SNeData/dsrg_accreted_particles.hdf5'
accreted = pd.read_hdf(path, key=key)

path = '/home/lonzaric/astro_research/Stellar_Feedback_Code/SNeData/tracked_particles_v2.hdf5'
tracked = read_tracked_particles('h148', 13, verbose=False)

# %%
discharged[discharged.pid==2202002]
accreted[accreted.pid==2202002]
# Out:
# Empty DataFrame
# Columns: [time, pid, rho, temp, mass, coolontime, r, r_per_Rvir, x, y, z, satRvir, a, vx, vy, vz, v, r_rel_host, r_rel_host_per_Rvir, x_rel_host, y_rel_host, z_rel_host, hostRvir, vx_rel_host, vy_rel_host, vz_rel_host, v_rel_host, sat_Xc, sat_Yc, sat_Zc, sat_vx, sat_vy, sat_vz, host_Xc, host_Yc, host_Zc, host_vx, host_vy, host_vz, sat_Mstar, sat_Mgas, host_Mstar, host_Mgas, sat_r_half, sat_r_gas, host_r_half, host_r_gas, in_sat, in_host, in_other_sat, in_IGM, dt, r_gal, host_r_gal, sat_disk, sat_halo, host_disk, host_halo, other_sat, IGM, t, sat_Mvir]
# Index: []
#
# [0 rows x 62 columns]

# %%
import tqdm

dsrg_accreted = pd.DataFrame() # gas accreted following a discharge event.


# picking out all unique particles that were tracked in a the dwarf galaxy.
pids = np.unique(tracked.pid) 
dsrg_pids = np.unique(discharged.pid)




for pid in tqdm.tqdm(dsrg_pids): # iterating over each unique pid.
    data = tracked[tracked.pid==pid] # picking out all instances of the particular particle (each has same # of timesteps).
    dsrg_data = discharged[discharged.pid==pid]


    sat_disk = np.array(data.sat_disk, dtype=bool)
    in_sat = np.array(data.in_sat, dtype=bool)
    outside_disk = ~sat_disk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_71104/1203719910.py in <module>
#       5
#       6 # picking out all unique particles that were tracked in a the dwarf galaxy.
# ----> 7 pids = np.unique(tracked.pid)
#       8 dsrg_pids = np.unique(discharged.pid)
#       9
#
# NameError: name 'tracked' is not defined

# %%
def calc_accreted(sim, haloid, save=True, verbose=True):
    ''' 
    Computing accreted gas particles using method 1: a particle is recorded as accreted 
    if it was present in the 'discharged' dataset prior to the accretion event.
    '''
    
    import tqdm
    
    tracked = read_tracked_particles(sim, haloid, verbose=verbose)# all gas at all recorded times.
    discharged = read_discharged(sim, haloid, verbose=verbose) # all gas ejected from the disk (can include repeat events).
    
#     if verbose: print(f'Now computing discharged particles for {sim}-{haloid}...')
    dsrg_accreted = pd.DataFrame() # gas accreted following a discharge event.
    
    
    # picking out all unique particles that were tracked in a the dwarf galaxy.
    pids = np.unique(tracked.pid) 
    dsrg_pids = np.unique(discharged.pid)
    
    
    
    
    for pid in tqdm.tqdm(dsrg_pids): # iterating over each unique pid.
        data = tracked[tracked.pid==pid] # picking out all instances of the particular particle (each has same # of timesteps).
        dsrg_data = discharged[discharged.pid==pid]
    
        
        sat_disk = np.array(data.sat_disk, dtype=bool)
        in_sat = np.array(data.in_sat, dtype=bool)
        outside_disk = ~sat_disk
        
        time = np.array(data.time, dtype=float)
        
                
            
         
            
            
        for i,t2 in enumerate(time[1:]): # iterating over all recorded timesteps for the particle.
                i += 1
                    
                if ( and sat_disk[i]):
                    _in_ = data[time==t2].copy()
                    dsrg_accreted = pd.concat([dsrg_accreted, _in_])
                 

                
                
                
                
                
    # apply the calc_angles function along the rows of discharged particles.
   
    
    if save:
        filepath = '/home/lonzaric/astro_research/Stellar_Feedback_Code/SNeData/accreted_test.hdf5'
        print(f'Saving {key} accreted particle dataset to {filepath}')
        dsrg_accreted.to_hdf(filepath, key=key)
        
        
    print(f'> Returning (dsrg_accreted) datasets <')

    return dsrg_accreted

# %% [markdown]
# ### Advanced Accretion Calculation:
# ______________________

# %%
def read_discharged(sim, haloid, verbose=False):
    discharged = pd.DataFrame()
    
    key = f'{sim}_{str(int(haloid))}'
    
    path = '/home/lonzaric/astro_research/Stellar_Feedback_Code/SNeData/discharged_particles.hdf5'
    discharged = pd.read_hdf(path, key=key)
    
    path = '/home/lonzaric/astro_research/Stellar_Feedback_Code/SNeData/dsrg_accreted_particles.hdf5'
    accreted = pd.read_hdf(path, key=key)
    
    return discharged, accreted

# %%
sim = 'h148'
haloid = 13
verbose = False

###############################################################################

import tqdm

discharged, accreted = read_discharged(sim, haloid, verbose=verbose)  

if verbose: print(f'Now computing discharged particles for {sim}-{haloid}...')
adv_accreted = pd.DataFrame() # gas accreted following a discharge event.

pids = np.unique(discharged.pid) # quicker to use discharge bc unique.

recycleTime = {'recycleTime': ""}
accreted = accreted.join(pd.DataFrame(columns=recycleTime))

for pid in tqdm.tqdm(pids):
    dis = discharged[discharged.pid==pid]
    acc = accreted[accreted.pid==pid]
    
    dTime = np.asarray(dis.time)
    aTime = np.asarray(acc.time)

    
    # Case 1: removing initial accretion event if it does not correspond to a discharge; else no alterations.
    # check to ensure that our discharge event actually has an accretion.
    if (len(aTime) == 0) or (len(dTime) == 0): # if no instances of accretion or no instances of discharge, move on to new particle
        continue
    if (aTime[0] < dTime[0]):
        aCache = acc[1:]
        
    else:
        aCache = acc
    
    if len(aCache) == 0: # if no instances of reaccretion, move on to next particle
        continue
        
    dCache = dis[0:len(aCache)]
       
    aCache['recycleTime'] = np.array(aCache['time']) - np.array(dCache['time'])
    print(dCache['time'],aCache['time'], aCache['recycleTime'])

    """
    recycleTime = pd.DataFrame([])
    for i in range(0, len(aCache)):
        i+=1
        dt = aCache.time.iloc[i] - dCache.time.iloc[i-1]

        recycleTime = pd.concat([recycleTime, dt])   
    
    print(recycleTime)
    # caching time between discharge and the recorded accretion.
    aCache['recycleTime'] = recycleTime
    """
    adv_accreted = pd.concat([adv_accreted, aCache])
# Out:
#   1%|▍                                       | 55/5276 [00:00<00:19, 274.47it/s]
# 190920    11.214915
# Name: time, dtype: float64 205282    11.645896
# Name: time, dtype: float64 205282    0.43098
# Name: recycleTime, dtype: float64
# 161854    10.7671
# Name: time, dtype: float64 161854    10.7671
# Name: time, dtype: float64 161854    0.0
# Name: recycleTime, dtype: float64
# 161858    10.7671
# Name: time, dtype: float64 161858    10.7671
# Name: time, dtype: float64 161858    0.0
# Name: recycleTime, dtype: float64
# 147226    10.352954
# Name: time, dtype: float64 219418    12.076876
# Name: time, dtype: float64 219418    1.723922
# Name: recycleTime, dtype: float64
# 190945    11.214915
# Name: time, dtype: float64 233230    12.150951
# Name: time, dtype: float64 233230    0.936036
# Name: recycleTime, dtype: float64
# 117820    9.490994
# Name: time, dtype: float64 117820    9.490994
# Name: time, dtype: float64 117820    0.0
# Name: recycleTime, dtype: float64
# 205311    11.645896
# Name: time, dtype: float64 260553    12.938837
# Name: time, dtype: float64 260553    1.292941
# Name: recycleTime, dtype: float64
# 117827    9.490994
# Name: time, dtype: float64 147236    10.352954
# Name: time, dtype: float64 147236    0.861961
# Name: recycleTime, dtype: float64
# 161895    10.7671
# Name: time, dtype: float64 205327    11.645896
# Name: time, dtype: float64 205327    0.878796
# Name: recycleTime, dtype: float64
# 103126    9.060013
# 132550    9.921974
# Name: time, dtype: float64 103126    9.060013
# 132550    9.921974
# Name: time, dtype: float64 103126    0.0
# 132550    0.0
# Name: recycleTime, dtype: float64
# 161904    10.7671
# Name: time, dtype: float64 176441    10.783935
# Name: time, dtype: float64 176441    0.016835
# Name: recycleTime, dtype: float64
# 117860    9.490994
# Name: time, dtype: float64 132570    9.921974
# Name: time, dtype: float64 132570    0.43098
# Name: recycleTime, dtype: float64
# 103218    9.060013
# Name: time, dtype: float64 205418    11.645896
# Name: time, dtype: float64 205418    2.585882
# Name: recycleTime, dtype: float64
# 117958     9.490994
# 147367    10.352954
# Name: time, dtype: float64 117958     9.490994
# 205443    11.645896
# Name: time, dtype: float64 117958    0.000000
# 205443    1.292941
# Name: recycleTime, dtype: float64
# 132671     9.921974
# 162016    10.767100
# 205446    11.645896
# Name: time, dtype: float64 132671     9.921974
# 176553    10.783935
# 205446    11.645896
# Name: time, dtype: float64 132671    0.000000
# 176553    0.016835
# 205446    0.000000
# Name: recycleTime, dtype: float64
# 147373    10.352954
# Name: time, dtype: float64 176556    10.783935
# Name: time, dtype: float64 176556    0.43098
# Name: recycleTime, dtype: float64
# 59107     7.767072
# 103274    9.060013
# Name: time, dtype: float64 73835     8.198053
# 103274    9.060013
# Name: time, dtype: float64 73835     0.43098
# 103274    0.00000
# Name: recycleTime, dtype: float64
# 29653    7.039793
# Name: time, dtype: float64 29653    7.039793
# Name: time, dtype: float64 29653    0.0
# Name: recycleTime, dtype: float64
# 14930    6.905111
# Name: time, dtype: float64 29658    7.039793
# Name: time, dtype: float64 29658    0.134681
# Name: recycleTime, dtype: float64
# 29672    7.039793
# Name: time, dtype: float64 29672    7.039793
# Name: time, dtype: float64 29672    0.0
# Name: recycleTime, dtype: float64
# 29673    7.039793
# Name: time, dtype: float64 29673    7.039793
# Name: time, dtype: float64 29673    0.0
# Name: recycleTime, dtype: float64
# 118011     9.490994
# 147420    10.352954
# Name: time, dtype: float64 118011     9.490994
# 147420    10.352954
# Name: time, dtype: float64 118011    0.0
# 147420    0.0
# Name: recycleTime, dtype: float64
# 44403    7.336092
# 88580    8.608831
# Name: time, dtype: float64 59131     7.767072
# 132722    9.921974
# Name: time, dtype: float64 59131     0.430980
# 132722    1.313143
# Name: recycleTime, dtype: float64
# 14948    6.905111
# Name: time, dtype: float64 44404    7.336092
# Name: time, dtype: float64 44404    0.43098
# Name: recycleTime, dtype: float64
# 14961    6.905111
# Name: time, dtype: float64 14961    6.905111
# Name: time, dtype: float64 14961    0.0
# Name: recycleTime, dtype: float64
# 59155    7.767072
# Name: time, dtype: float64 59155    7.767072
# Name: time, dtype: float64 59155    0.0
# Name: recycleTime, dtype: float64
#   2%|▊                                      | 112/5276 [00:00<00:19, 261.47it/s]
# 14974     6.905111
# 132749    9.921974
# Name: time, dtype: float64 14974     6.905111
# 132749    9.921974
# Name: time, dtype: float64 14974     0.0
# 132749    0.0
# Name: recycleTime, dtype: float64
# 118040     9.490994
# 162094    10.767100
# Name: time, dtype: float64 132750     9.921974
# 176631    10.783935
# Name: time, dtype: float64 132750    0.430980
# 176631    0.016835
# Name: recycleTime, dtype: float64
# 103328    9.060013
# Name: time, dtype: float64 103328    9.060013
# Name: time, dtype: float64 103328    0.0
# Name: recycleTime, dtype: float64
# 59164    7.767072
# 88613    8.608831
# Name: time, dtype: float64 59164    7.767072
# 88613    8.608831
# Name: time, dtype: float64 59164    0.0
# 88613    0.0
# Name: recycleTime, dtype: float64
# 14981    6.905111
# Name: time, dtype: float64 59165    7.767072
# Name: time, dtype: float64 59165    0.861961
# Name: recycleTime, dtype: float64
# 14982    6.905111
# Name: time, dtype: float64 44438    7.336092
# Name: time, dtype: float64 44438    0.43098
# Name: recycleTime, dtype: float64
# 14993    6.905111
# 59177    7.767072
# Name: time, dtype: float64 14993    6.905111
# 59177    7.767072
# Name: time, dtype: float64 14993    0.0
# 59177    0.0
# Name: recycleTime, dtype: float64
# 29725    7.039793
# Name: time, dtype: float64 29725    7.039793
# Name: time, dtype: float64 29725    0.0
# Name: recycleTime, dtype: float64
# 15002    6.905111
# 44458    7.336092
# Name: time, dtype: float64 15002    6.905111
# 73914    8.198053
# Name: time, dtype: float64 15002    0.000000
# 73914    0.861961
# Name: recycleTime, dtype: float64
# 15006    6.905111
# 44462    7.336092
# 88639    8.608831
# Name: time, dtype: float64 15006     6.905111
# 44462     7.336092
# 103357    9.060013
# Name: time, dtype: float64 15006     0.000000
# 44462     0.000000
# 103357    0.451183
# Name: recycleTime, dtype: float64
# 15016    6.905111
# Name: time, dtype: float64 44472    7.336092
# Name: time, dtype: float64 44472    0.43098
# Name: recycleTime, dtype: float64
# 44473    7.336092
# Name: time, dtype: float64 59201    7.767072
# Name: time, dtype: float64 59201    0.43098
# Name: recycleTime, dtype: float64
# 88651    8.608831
# Name: time, dtype: float64 88651    8.608831
# Name: time, dtype: float64 88651    0.0
# Name: recycleTime, dtype: float64
# 44483    7.336092
# Name: time, dtype: float64 59211    7.767072
# Name: time, dtype: float64 59211    0.43098
# Name: recycleTime, dtype: float64
# 15028     6.905111
# 59212     7.767072
# 88661     8.608831
# 118093    9.490994
# Name: time, dtype: float64 15028     6.905111
# 59212     7.767072
# 88661     8.608831
# 118093    9.490994
# Name: time, dtype: float64 15028     0.0
# 59212     0.0
# 88661     0.0
# 118093    0.0
# Name: recycleTime, dtype: float64
# 15038    6.905111
# 73950    8.198053
# Name: time, dtype: float64 29766    7.039793
# 73950    8.198053
# Name: time, dtype: float64 29766    0.134681
# 73950    0.000000
# Name: recycleTime, dtype: float64
# 44496    7.336092
# Name: time, dtype: float64 59224    7.767072
# Name: time, dtype: float64 59224    0.43098
# Name: recycleTime, dtype: float64
# 15124    6.905111
# Name: time, dtype: float64 74036    8.198053
# Name: time, dtype: float64 74036    1.292941
# Name: recycleTime, dtype: float64
# 59312      7.767072
# 118193     9.490994
# 205670    11.645896
# Name: time, dtype: float64 59312      7.767072
# 176781    10.783935
# 205670    11.645896
# Name: time, dtype: float64 59312     0.000000
# 176781    1.292941
# 205670    0.000000
# Name: recycleTime, dtype: float64
# 29858    7.039793
# Name: time, dtype: float64 59314    7.767072
# Name: time, dtype: float64 59314    0.727279
# Name: recycleTime, dtype: float64
# 59317      7.767072
# 162249    10.767100
# Name: time, dtype: float64 132908     9.921974
# 176786    10.783935
# Name: time, dtype: float64 132908    2.154902
# 176786    0.016835
# Name: recycleTime, dtype: float64
# 29863    7.039793
# Name: time, dtype: float64 29863    7.039793
# Name: time, dtype: float64 29863    0.0
# Name: recycleTime, dtype: float64
# 15137    6.905111
# Name: time, dtype: float64 15137    6.905111
# Name: time, dtype: float64 15137    0.0
# Name: recycleTime, dtype: float64
# 29866    7.039793
# Name: time, dtype: float64 29866    7.039793
# Name: time, dtype: float64 29866    0.0
# Name: recycleTime, dtype: float64
# 59328    7.767072
# 88777    8.608831
# Name: time, dtype: float64 59328     7.767072
# 132919    9.921974
# Name: time, dtype: float64 59328     0.000000
# 132919    1.313143
# Name: recycleTime, dtype: float64
# 29873    7.039793
# Name: time, dtype: float64 29873    7.039793
# Name: time, dtype: float64 29873    0.0
# Name: recycleTime, dtype: float64
# 15146     6.905111
# 88779     8.608831
# 118211    9.490994
# Name: time, dtype: float64 44602     7.336092
# 88779     8.608831
# 118211    9.490994
# Name: time, dtype: float64 44602     0.43098
# 88779     0.00000
# 118211    0.00000
# Name: recycleTime, dtype: float64
# 15147    6.905111
# Name: time, dtype: float64 59331    7.767072
# Name: time, dtype: float64 59331    0.861961
# Name: recycleTime, dtype: float64
# 103500     9.060013
# 162265    10.767100
# Name: time, dtype: float64 118214     9.490994
# 176802    10.783935
# Name: time, dtype: float64 118214    0.430980
# 176802    0.016835
# Name: recycleTime, dtype: float64
# 74062     8.198053
# 118215    9.490994
# Name: time, dtype: float64 88783     8.608831
# 118215    9.490994
# Name: time, dtype: float64 88783     0.410778
# 118215    0.000000
# Name: recycleTime, dtype: float64
# 15151    6.905111
# Name: time, dtype: float64 29879    7.039793
# Name: time, dtype: float64 29879    0.134681
# Name: recycleTime, dtype: float64
# 15158    6.905111
# 88791    8.608831
# Name: time, dtype: float64 29886      7.039793
# 219802    12.076876
# Name: time, dtype: float64 29886     0.134681
# 219802    3.468045
# Name: recycleTime, dtype: float64
# 88794      8.608831
# 118226     9.490994
# 147634    10.352954
# Name: time, dtype: float64
#   3%|█                                      | 140/5276 [00:00<00:19, 266.29it/s]
#  88794      8.608831
# 118226     9.490994
# 147634    10.352954
# Name: time, dtype: float64 88794     0.0
# 118226    0.0
# 147634    0.0
# Name: recycleTime, dtype: float64
# 29890      7.039793
# 103513     9.060013
# 176815    10.783935
# Name: time, dtype: float64 44618      7.336092
# 147635    10.352954
# 176815    10.783935
# Name: time, dtype: float64 44618     0.296299
# 147635    1.292941
# 176815    0.000000
# Name: recycleTime, dtype: float64
# 88796      8.608831
# 132938     9.921974
# 176816    10.783935
# Name: time, dtype: float64 103514     9.060013
# 132938     9.921974
# 205704    11.645896
# Name: time, dtype: float64 103514    0.451183
# 132938    0.000000
# 205704    0.861961
# Name: recycleTime, dtype: float64
# 15167    6.905111
# Name: time, dtype: float64 15167    6.905111
# Name: time, dtype: float64 15167    0.0
# Name: recycleTime, dtype: float64
# 118235     9.490994
# 162286    10.767100
# Name: time, dtype: float64 132945     9.921974
# 219814    12.076876
# Name: time, dtype: float64 132945    0.430980
# 219814    1.309776
# Name: recycleTime, dtype: float64
# 118304    9.490994
# Name: time, dtype: float64 162355    10.7671
# Name: time, dtype: float64 162355    1.276106
# Name: recycleTime, dtype: float64
# 74206    8.198053
# Name: time, dtype: float64 74206    8.198053
# Name: time, dtype: float64 74206    0.0
# Name: recycleTime, dtype: float64
# 44781    7.336092
# Name: time, dtype: float64 44781    7.336092
# Name: time, dtype: float64 44781    0.0
# Name: recycleTime, dtype: float64
# 15326    6.905111
# Name: time, dtype: float64 15326    6.905111
# Name: time, dtype: float64 15326    0.0
# Name: recycleTime, dtype: float64
# 118418     9.490994
# 147826    10.352954
# Name: time, dtype: float64 118418     9.490994
# 147826    10.352954
# Name: time, dtype: float64 118418    0.0
# 147826    0.0
# Name: recycleTime, dtype: float64
# 59553    7.767072
# Name: time, dtype: float64 59553    7.767072
# Name: time, dtype: float64 59553    0.0
# Name: recycleTime, dtype: float64
# 15370    6.905111
# Name: time, dtype: float64 15370    6.905111
# Name: time, dtype: float64 15370    0.0
# Name: recycleTime, dtype: float64
# 103731    9.060013
# Name: time, dtype: float64 118445    9.490994
# Name: time, dtype: float64 118445    0.43098
# Name: recycleTime, dtype: float64
# 15382    6.905111
# Name: time, dtype: float64 44838    7.336092
# Name: time, dtype: float64 44838    0.43098
# Name: recycleTime, dtype: float64
# 44842    7.336092
# Name: time, dtype: float64 44842    7.336092
# Name: time, dtype: float64 44842    0.0
# Name: recycleTime, dtype: float64
# 15387    6.905111
# Name: time, dtype: float64 15387    6.905111
# Name: time, dtype: float64 15387    0.0
# Name: recycleTime, dtype: float64
# 30116    7.039793
# 59572    7.767072
# Name: time, dtype: float64 30116    7.039793
# 59572    7.767072
# Name: time, dtype: float64 30116    0.0
# 59572    0.0
# Name: recycleTime, dtype: float64
# 74301     8.198053
# 103740    9.060013
# Name: time, dtype: float64 74301     8.198053
# 103740    9.060013
# Name: time, dtype: float64 74301     0.0
# 103740    0.0
# Name: recycleTime, dtype: float64
# 30120     7.039793
# 59576     7.767072
# 103743    9.060013
# Name: time, dtype: float64 30120     7.039793
# 59576     7.767072
# 118457    9.490994
# Name: time, dtype: float64 30120     0.00000
# 59576     0.00000
# 118457    0.43098
# Name: recycleTime, dtype: float64
# 89026    8.608831
# Name: time, dtype: float64 103744    9.060013
# Name: time, dtype: float64 103744    0.451183
# Name: recycleTime, dtype: float64
# 15394    6.905111
# 89027    8.608831
# Name: time, dtype: float64 15394    6.905111
# 89027    8.608831
# Name: time, dtype: float64 15394    0.0
# 89027    0.0
# Name: recycleTime, dtype: float64
# 30125    7.039793
# Name: time, dtype: float64 44853    7.336092
# Name: time, dtype: float64 44853    0.296299
# Name: recycleTime, dtype: float64
# 59584    7.767072
# Name: time, dtype: float64 74312    8.198053
# Name: time, dtype: float64 74312    0.43098
# Name: recycleTime, dtype: float64
# 44858      7.336092
# 74314      8.198053
# 118467     9.490994
# 147875    10.352954
# Name: time, dtype: float64 44858      7.336092
# 89035      8.608831
# 118467     9.490994
# 233840    12.150951
# Name: time, dtype: float64 44858     0.000000
# 89035     0.410778
# 118467    0.000000
# 233840    1.797996
# Name: recycleTime, dtype: float64
# 44868    7.336092
# Name: time, dtype: float64 44868    7.336092
# Name: time, dtype: float64 44868    0.0
# Name: recycleTime, dtype: float64
# 30142    7.039793
# Name: time, dtype: float64 44870    7.336092
# Name: time, dtype: float64 44870    0.296299
# Name: recycleTime, dtype: float64
# 15417    6.905111
# Name: time, dtype: float64 30145    7.039793
# Name: time, dtype: float64 30145    0.134681
# Name: recycleTime, dtype: float64
# 44874    7.336092
# Name: time, dtype: float64 74330    8.198053
# Name: time, dtype: float64 74330    0.861961
# Name: recycleTime, dtype: float64
# 30148    7.039793
# Name: time, dtype: float64 44876    7.336092
# Name: time, dtype: float64 44876    0.296299
# Name: recycleTime, dtype: float64
# 59606    7.767072
# Name: time, dtype: float64 59606    7.767072
# Name: time, dtype: float64 59606    0.0
# Name: recycleTime, dtype: float64
# 15438    6.905111
# 44894    7.336092
# Name: time, dtype: float64 15438    6.905111
# 44894    7.336092
# Name: time, dtype: float64 15438    0.0
# 44894    0.0
# Name: recycleTime, dtype: float64
# 89075     8.608831
# 118507    9.490994
# Name: time, dtype: float64 89075     8.608831
# 133217    9.921974
# Name: time, dtype: float64 89075     0.00000
# 133217    0.43098
# Name: recycleTime, dtype: float64
#   4%|█▋                                     | 232/5276 [00:00<00:16, 299.36it/s]
# 44905      7.336092
# 74361      8.198053
# 103800     9.060013
# 162565    10.767100
# Name: time, dtype: float64 44905      7.336092
# 74361      8.198053
# 133224     9.921974
# 220076    12.076876
# Name: time, dtype: float64 44905     0.000000
# 74361     0.000000
# 133224    0.861961
# 220076    1.309776
# Name: recycleTime, dtype: float64
# 30183      7.039793
# 74367      8.198053
# 103806     9.060013
# 147928    10.352954
# Name: time, dtype: float64 30183      7.039793
# 74367      8.198053
# 103806     9.060013
# 147928    10.352954
# Name: time, dtype: float64 30183     0.0
# 74367     0.0
# 103806    0.0
# 147928    0.0
# Name: recycleTime, dtype: float64
# 15458      6.905111
# 118523     9.490994
# 205990    11.645896
# Name: time, dtype: float64 44914      7.336092
# 177111    10.783935
# 220085    12.076876
# Name: time, dtype: float64 44914     0.430980
# 177111    1.292941
# 220085    0.430980
# Name: recycleTime, dtype: float64
# 15461    6.905111
# Name: time, dtype: float64 30189    7.039793
# Name: time, dtype: float64 30189    0.134681
# Name: recycleTime, dtype: float64
# 103816    9.060013
# 133240    9.921974
# Name: time, dtype: float64 103816    9.060013
# 133240    9.921974
# Name: time, dtype: float64 103816    0.0
# 133240    0.0
# Name: recycleTime, dtype: float64
# 30197    7.039793
# 59653    7.767072
# Name: time, dtype: float64 30197    7.039793
# 59653    7.767072
# Name: time, dtype: float64 30197    0.0
# 59653    0.0
# Name: recycleTime, dtype: float64
# 44928    7.336092
# Name: time, dtype: float64 44928    7.336092
# Name: time, dtype: float64 44928    0.0
# Name: recycleTime, dtype: float64
# 30204    7.039793
# Name: time, dtype: float64 30204    7.039793
# Name: time, dtype: float64 30204    0.0
# Name: recycleTime, dtype: float64
# 30205    7.039793
# 59661    7.767072
# Name: time, dtype: float64 30205    7.039793
# 74389    8.198053
# Name: time, dtype: float64 30205    0.00000
# 74389    0.43098
# Name: recycleTime, dtype: float64
# 15480     6.905111
# 103831    9.060013
# Name: time, dtype: float64 15480     6.905111
# 118545    9.490994
# Name: time, dtype: float64 15480     0.00000
# 118545    0.43098
# Name: recycleTime, dtype: float64
# 30218    7.039793
# Name: time, dtype: float64 30218    7.039793
# Name: time, dtype: float64 30218    0.0
# Name: recycleTime, dtype: float64
# 44947    7.336092
# 74403    8.198053
# Name: time, dtype: float64 44947    7.336092
# 74403    8.198053
# Name: time, dtype: float64 44947    0.0
# 74403    0.0
# Name: recycleTime, dtype: float64
# 44951    7.336092
# Name: time, dtype: float64 44951    7.336092
# Name: time, dtype: float64 44951    0.0
# Name: recycleTime, dtype: float64
# 30226    7.039793
# Name: time, dtype: float64 30226    7.039793
# Name: time, dtype: float64 30226    0.0
# Name: recycleTime, dtype: float64
# 15507    6.905111
# 74419    8.198053
# Name: time, dtype: float64 44963    7.336092
# 74419    8.198053
# Name: time, dtype: float64 44963    0.43098
# 74419    0.00000
# Name: recycleTime, dtype: float64
# 15514     6.905111
# 44970     7.336092
# 74426     8.198053
# 118579    9.490994
# Name: time, dtype: float64 15514     6.905111
# 44970     7.336092
# 74426     8.198053
# 118579    9.490994
# Name: time, dtype: float64 15514     0.0
# 44970     0.0
# 74426     0.0
# 118579    0.0
# Name: recycleTime, dtype: float64
# 15517    6.905111
# Name: time, dtype: float64 44973    7.336092
# Name: time, dtype: float64 44973    0.43098
# Name: recycleTime, dtype: float64
# 15519    6.905111
# Name: time, dtype: float64 15519    6.905111
# Name: time, dtype: float64 15519    0.0
# Name: recycleTime, dtype: float64
# 30257    7.039793
# Name: time, dtype: float64 30257    7.039793
# Name: time, dtype: float64 30257    0.0
# Name: recycleTime, dtype: float64
# 44990     7.336092
# 103885    9.060013
# 133309    9.921974
# Name: time, dtype: float64 44990      7.336092
# 103885     9.060013
# 220156    12.076876
# Name: time, dtype: float64 44990     0.000000
# 103885    0.000000
# 220156    2.154902
# Name: recycleTime, dtype: float64
# 44992    7.336092
# 74448    8.198053
# Name: time, dtype: float64 44992    7.336092
# 74448    8.198053
# Name: time, dtype: float64 44992    0.0
# 74448    0.0
# Name: recycleTime, dtype: float64
# 44996    7.336092
# Name: time, dtype: float64 59724    7.767072
# Name: time, dtype: float64 59724    0.43098
# Name: recycleTime, dtype: float64
# 103893    9.060013
# Name: time, dtype: float64 233972    12.150951
# Name: time, dtype: float64 233972    3.090937
# Name: recycleTime, dtype: float64
# 45018    7.336092
# 89194    8.608831
# Name: time, dtype: float64 59746    7.767072
# 89194    8.608831
# Name: time, dtype: float64 59746    0.43098
# 89194    0.00000
# Name: recycleTime, dtype: float64
# 15566    6.905111
# Name: time, dtype: float64 45022    7.336092
# Name: time, dtype: float64 45022    0.43098
# Name: recycleTime, dtype: float64
# 45023    7.336092
# Name: time, dtype: float64 45023    7.336092
# Name: time, dtype: float64 45023    0.0
# Name: recycleTime, dtype: float64
# 15568    6.905111
# Name: time, dtype: float64 15568    6.905111
# Name: time, dtype: float64 15568    0.0
# Name: recycleTime, dtype: float64
# 15572    6.905111
# Name: time, dtype: float64 59756    7.767072
# Name: time, dtype: float64 59756    0.861961
# Name: recycleTime, dtype: float64
# 15586    6.905111
# Name: time, dtype: float64 45042    7.336092
# Name: time, dtype: float64 45042    0.43098
# Name: recycleTime, dtype: float64
# 45043      7.336092
# 103937     9.060013
# 148058    10.352954
# 191762    11.214915
# Name: time, dtype: float64 59771      7.767072
# 118651     9.490994
# 148058    10.352954
# 220208    12.076876
# Name: time, dtype: float64 59771     0.430980
# 118651    0.430980
# 148058    0.000000
# 220208    0.861961
# Name: recycleTime, dtype: float64
# 118652    9.490994
# Name: time, dtype: float64 220209    12.076876
# Name: time, dtype: float64 220209    2.585882
# Name: recycleTime, dtype: float64
# 30319    7.039793
# Name: time, dtype: float64 30319    7.039793
# Name: time, dtype: float64 30319    0.0
# Name: recycleTime, dtype: float64
# 15592    6.905111
# 59776    7.767072
# Name: time, dtype: float64 30320    7.039793
# 59776    7.767072
# Name: time, dtype: float64 30320    0.134681
# 59776    0.000000
# Name: recycleTime, dtype: float64
# 30322    7.039793
# Name: time, dtype: float64 45050    7.336092
# Name: time, dtype: float64 45050    0.296299
# Name: recycleTime, dtype: float64
# 15598    6.905111
# Name: time, dtype: float64 15598    6.905111
# Name: time, dtype: float64 15598    0.0
# Name: recycleTime, dtype: float64
# 30329    7.039793
# Name: time, dtype: float64 30329    7.039793
# Name: time, dtype: float64 30329    0.0
# Name: recycleTime, dtype: float64
# 118667     9.490994
# 148074    10.352954
# 206129    11.645896
# Name: time, dtype: float64 118667     9.490994
# 177254    10.783935
# 206129    11.645896
# Name: time, dtype: float64 118667    0.00000
# 177254    0.43098
# 206129    0.00000
# Name: recycleTime, dtype: float64
# 59804    7.767072
# 89252    8.608831
# Name: time, dtype: float64 59804     7.767072
# 103970    9.060013
# Name: time, dtype: float64 59804     0.000000
# 103970    0.451183
# Name: recycleTime, dtype: float64
# 30362    7.039793
# Name: time, dtype: float64 30362    7.039793
# Name: time, dtype: float64 30362    0.0
# Name: recycleTime, dtype: float64
# 15638    6.905111
# 59822    7.767072
# Name: time, dtype: float64 15638    6.905111
# 74549    8.198053
# Name: time, dtype: float64 15638    0.00000
# 74549    0.43098
# Name: recycleTime, dtype: float64
# 74550    8.198053
# Name: time, dtype: float64 74550    8.198053
# Name: time, dtype: float64 74550    0.0
# Name: recycleTime, dtype: float64
# 59833    7.767072
# 89281    8.608831
# Name: time, dtype: float64 59833    7.767072
# 89281    8.608831
# Name: time, dtype: float64 59833    0.0
# 89281    0.0
# Name: recycleTime, dtype: float64
#   6%|██▎                                    | 316/5276 [00:01<00:13, 359.83it/s]
# 89282    8.608831
# Name: time, dtype: float64 118714    9.490994
# Name: time, dtype: float64 118714    0.882163
# Name: recycleTime, dtype: float64
# 15652      6.905111
# 45108      7.336092
# 89284      8.608831
# 148123    10.352954
# 206176    11.645896
# Name: time, dtype: float64 15652      6.905111
# 45108      7.336092
# 104002     9.060013
# 177303    10.783935
# 220270    12.076876
# Name: time, dtype: float64 15652     0.000000
# 45108     0.000000
# 104002    0.451183
# 177303    0.430980
# 220270    0.430980
# Name: recycleTime, dtype: float64
# 118724    9.490994
# Name: time, dtype: float64 118724    9.490994
# Name: time, dtype: float64 118724    0.0
# Name: recycleTime, dtype: float64
# 30392    7.039793
# Name: time, dtype: float64 30392    7.039793
# Name: time, dtype: float64 30392    0.0
# Name: recycleTime, dtype: float64
# 15667    6.905111
# Name: time, dtype: float64 30395    7.039793
# Name: time, dtype: float64 30395    0.134681
# Name: recycleTime, dtype: float64
# 30396    7.039793
# 59852    7.767072
# Name: time, dtype: float64 30396    7.039793
# 59852    7.767072
# Name: time, dtype: float64 30396    0.0
# 59852    0.0
# Name: recycleTime, dtype: float64
# 30422      7.039793
# 59878      7.767072
# 89326      8.608831
# 118758     9.490994
# 162808    10.767100
# Name: time, dtype: float64 30422      7.039793
# 59878      7.767072
# 89326      8.608831
# 118758     9.490994
# 177345    10.783935
# Name: time, dtype: float64 30422     0.000000
# 59878     0.000000
# 89326     0.000000
# 118758    0.000000
# 177345    0.016835
# Name: recycleTime, dtype: float64
# 177355    10.783935
# Name: time, dtype: float64 206226    11.645896
# Name: time, dtype: float64 206226    0.861961
# Name: recycleTime, dtype: float64
# 15713    6.905111
# Name: time, dtype: float64 30441    7.039793
# Name: time, dtype: float64 30441    0.134681
# Name: recycleTime, dtype: float64
# 104067    9.060013
# Name: time, dtype: float64 118781    9.490994
# Name: time, dtype: float64 118781    0.43098
# Name: recycleTime, dtype: float64
# 30447    7.039793
# Name: time, dtype: float64 30447    7.039793
# Name: time, dtype: float64 30447    0.0
# Name: recycleTime, dtype: float64
# 118790    9.490994
# Name: time, dtype: float64 148197    10.352954
# Name: time, dtype: float64 148197    0.861961
# Name: recycleTime, dtype: float64
# 15727    6.905111
# Name: time, dtype: float64 30455    7.039793
# Name: time, dtype: float64 30455    0.134681
# Name: recycleTime, dtype: float64
# 45191    7.336092
# Name: time, dtype: float64 59919    7.767072
# Name: time, dtype: float64 59919    0.43098
# Name: recycleTime, dtype: float64
# 118800    9.490994
# Name: time, dtype: float64 133510    9.921974
# Name: time, dtype: float64 133510    0.43098
# Name: recycleTime, dtype: float64
# 15738    6.905111
# Name: time, dtype: float64 15738    6.905111
# Name: time, dtype: float64 15738    0.0
# Name: recycleTime, dtype: float64
# 45196    7.336092
# Name: time, dtype: float64 45196    7.336092
# Name: time, dtype: float64 45196    0.0
# Name: recycleTime, dtype: float64
# 15747    6.905111
# Name: time, dtype: float64 30475    7.039793
# Name: time, dtype: float64 30475    0.134681
# Name: recycleTime, dtype: float64
# 15776    6.905111
# 45232    7.336092
# Name: time, dtype: float64 15776    6.905111
# 45232    7.336092
# Name: time, dtype: float64 15776    0.0
# 45232    0.0
# Name: recycleTime, dtype: float64
# 118852     9.490994
# 177438    10.783935
# Name: time, dtype: float64 148258    10.352954
# 177438    10.783935
# Name: time, dtype: float64 148258    0.861961
# 177438    0.000000
# Name: recycleTime, dtype: float64
# 74716    8.198053
# Name: time, dtype: float64 74716    8.198053
# Name: time, dtype: float64 74716    0.0
# Name: recycleTime, dtype: float64
# 74717      8.198053
# 133580     9.921974
# 162919    10.767100
# Name: time, dtype: float64 74717      8.198053
# 133580     9.921974
# 220418    12.076876
# Name: time, dtype: float64 74717     0.000000
# 133580    0.000000
# 220418    1.309776
# Name: recycleTime, dtype: float64
# 59992     7.767072
# 89440     8.608831
# 118872    9.490994
# Name: time, dtype: float64 59992     7.767072
# 89440     8.608831
# 133582    9.921974
# Name: time, dtype: float64 59992     0.00000
# 89440     0.00000
# 133582    0.43098
# Name: recycleTime, dtype: float64
# 15825    6.905111
# Name: time, dtype: float64 15825    6.905111
# Name: time, dtype: float64 15825    0.0
# Name: recycleTime, dtype: float64
# 89458    8.608831
# Name: time, dtype: float64 148296    10.352954
# Name: time, dtype: float64 148296    1.744124
# Name: recycleTime, dtype: float64
# 74778     8.198053
# 104217    9.060013
# Name: time, dtype: float64 74778     8.198053
# 118931    9.490994
# Name: time, dtype: float64 74778     0.00000
# 118931    0.43098
# Name: recycleTime, dtype: float64
# 15869    6.905111
# 74780    8.198053
# Name: time, dtype: float64 30597    7.039793
# 74780    8.198053
# Name: time, dtype: float64 30597    0.134681
# 74780    0.000000
# Name: recycleTime, dtype: float64
# 74801     8.198053
# 104240    9.060013
# Name: time, dtype: float64 74801     8.198053
# 133664    9.921974
# Name: time, dtype: float64 74801     0.000000
# 133664    0.861961
# Name: recycleTime, dtype: float64
# 104242     9.060013
# 133666     9.921974
# 163005    10.767100
# 220502    12.076876
# Name: time, dtype: float64 104242     9.060013
# 133666     9.921974
# 192063    11.214915
# 220502    12.076876
# Name: time, dtype: float64 104242    0.000000
# 133666    0.000000
# 192063    0.447816
# 220502    0.000000
# Name: recycleTime, dtype: float64
# 15893    6.905111
# 60077    7.767072
# Name: time, dtype: float64 15893    6.905111
# 60077    7.767072
# Name: time, dtype: float64 15893    0.0
# 60077    0.0
# Name: recycleTime, dtype: float64
# 74808     8.198053
# 118961    9.490994
# Name: time, dtype: float64 89529      8.608831
# 206415    11.645896
# Name: time, dtype: float64 89529     0.410778
# 206415    2.154902
# Name: recycleTime, dtype: float64
# 15901    6.905111
# Name: time, dtype: float64 15901    6.905111
# Name: time, dtype: float64 15901    0.0
# Name: recycleTime, dtype: float64
# 45361    7.336092
# Name: time, dtype: float64 45361    7.336092
# Name: time, dtype: float64 45361    0.0
# Name: recycleTime, dtype: float64
# 30640    7.039793
# Name: time, dtype: float64 30640    7.039793
# Name: time, dtype: float64 30640    0.0
# Name: recycleTime, dtype: float64
# 15922    6.905111
# 45378    7.336092
# Name: time, dtype: float64 15922    6.905111
# 60106    7.767072
# Name: time, dtype: float64 15922    0.00000
# 60106    0.43098
# Name: recycleTime, dtype: float64
# 45380    7.336092
# Name: time, dtype: float64 74835    8.198053
# Name: time, dtype: float64 74835    0.861961
# Name: recycleTime, dtype: float64
# 15939    6.905111
# Name: time, dtype: float64 15939    6.905111
# Name: time, dtype: float64 15939    0.0
# Name: recycleTime, dtype: float64
# 45400    7.336092
# Name: time, dtype: float64 60128    7.767072
# Name: time, dtype: float64 60128    0.43098
# Name: recycleTime, dtype: float64
# 104304     9.060013
# 163067    10.767100
# Name: time, dtype: float64 133728     9.921974
# 206470    11.645896
# Name: time, dtype: float64 133728    0.861961
# 206470    0.878796
# Name: recycleTime, dtype: float64
# 15963    6.905111
# Name: time, dtype: float64 45419    7.336092
# Name: time, dtype: float64 45419    0.43098
# Name: recycleTime, dtype: float64
# 60151     7.767072
# 89599     8.608831
# 119031    9.490994
# Name: time, dtype: float64 60151      7.767072
# 89599      8.608831
# 163080    10.767100
# Name: time, dtype: float64 60151     0.000000
# 89599     0.000000
# 163080    1.276106
# Name: recycleTime, dtype: float64
#   7%|██▌                                    | 353/5276 [00:01<00:13, 352.73it/s]
# 30697    7.039793
# Name: time, dtype: float64 30697    7.039793
# Name: time, dtype: float64 30697    0.0
# Name: recycleTime, dtype: float64
# 104320    9.060013
# Name: time, dtype: float64 148440    10.352954
# Name: time, dtype: float64 148440    1.292941
# Name: recycleTime, dtype: float64
# 15974    6.905111
# Name: time, dtype: float64 30702    7.039793
# Name: time, dtype: float64 30702    0.134681
# Name: recycleTime, dtype: float64
# 30707      7.039793
# 60163      7.767072
# 104329     9.060013
# 133753     9.921974
# 163092    10.767100
# Name: time, dtype: float64 30707      7.039793
# 60163      7.767072
# 104329     9.060013
# 133753     9.921974
# 177629    10.783935
# Name: time, dtype: float64 30707     0.000000
# 60163     0.000000
# 104329    0.000000
# 133753    0.000000
# 177629    0.016835
# Name: recycleTime, dtype: float64
# 15980    6.905111
# 60164    7.767072
# Name: time, dtype: float64 30708    7.039793
# 60164    7.767072
# Name: time, dtype: float64 30708    0.134681
# 60164    0.000000
# Name: recycleTime, dtype: float64
# 15984    6.905111
# Name: time, dtype: float64 60168    7.767072
# Name: time, dtype: float64 60168    0.861961
# Name: recycleTime, dtype: float64
# 119049     9.490994
# 148455    10.352954
# 192156    11.214915
# 234398    12.150951
# Name: time, dtype: float64 119049     9.490994
# 148455    10.352954
# 206501    11.645896
# 234398    12.150951
# Name: time, dtype: float64 119049    0.00000
# 148455    0.00000
# 206501    0.43098
# 234398    0.00000
# Name: recycleTime, dtype: float64
# 30718    7.039793
# Name: time, dtype: float64 30718    7.039793
# Name: time, dtype: float64 30718    0.0
# Name: recycleTime, dtype: float64
# 15997    6.905111
# Name: time, dtype: float64 45453    7.336092
# Name: time, dtype: float64 45453    0.43098
# Name: recycleTime, dtype: float64
# 15999    6.905111
# Name: time, dtype: float64 30727    7.039793
# Name: time, dtype: float64 30727    0.134681
# Name: recycleTime, dtype: float64
# 16007    6.905111
# Name: time, dtype: float64 45463    7.336092
# Name: time, dtype: float64 45463    0.43098
# Name: recycleTime, dtype: float64
# 45464    7.336092
# Name: time, dtype: float64 45464    7.336092
# Name: time, dtype: float64 45464    0.0
# Name: recycleTime, dtype: float64
# 16011     6.905111
# 119075    9.490994
# Name: time, dtype: float64 30739     7.039793
# 119075    9.490994
# Name: time, dtype: float64 30739     0.134681
# 119075    0.000000
# Name: recycleTime, dtype: float64
# 45480    7.336092
# Name: time, dtype: float64 74935    8.198053
# Name: time, dtype: float64 74935    0.861961
# Name: recycleTime, dtype: float64
# 89660    8.608831
# Name: time, dtype: float64 133802    9.921974
# Name: time, dtype: float64 133802    1.313143
# Name: recycleTime, dtype: float64
# 16031    6.905111
# Name: time, dtype: float64 16031    6.905111
# Name: time, dtype: float64 16031    0.0
# Name: recycleTime, dtype: float64
# 45491    7.336092
# Name: time, dtype: float64 60219    7.767072
# Name: time, dtype: float64 60219    0.43098
# Name: recycleTime, dtype: float64
# 30768    7.039793
# Name: time, dtype: float64 45496    7.336092
# Name: time, dtype: float64 45496    0.296299
# Name: recycleTime, dtype: float64
# 16045    6.905111
# 60229    7.767072
# Name: time, dtype: float64 30773    7.039793
# 60229    7.767072
# Name: time, dtype: float64 30773    0.134681
# 60229    0.000000
# Name: recycleTime, dtype: float64
# 119119     9.490994
# 220656    12.076876
# Name: time, dtype: float64 192224    11.214915
# 234463    12.150951
# Name: time, dtype: float64 192224    1.723922
# 234463    0.074075
# Name: recycleTime, dtype: float64
# 45513     7.336092
# 104407    9.060013
# Name: time, dtype: float64 45513     7.336092
# 104407    9.060013
# Name: time, dtype: float64 45513     0.0
# 104407    0.0
# Name: recycleTime, dtype: float64
# 30786    7.039793
# 60242    7.767072
# Name: time, dtype: float64 30786     7.039793
# 133831    9.921974
# Name: time, dtype: float64 30786     0.000000
# 133831    2.154902
# Name: recycleTime, dtype: float64
# 16059     6.905111
# 89691     8.608831
# 119122    9.490994
# Name: time, dtype: float64 45515     7.336092
# 89691     8.608831
# 119122    9.490994
# Name: time, dtype: float64 45515     0.43098
# 89691     0.00000
# 119122    0.00000
# Name: recycleTime, dtype: float64
# 16060    6.905111
# 60244    7.767072
# Name: time, dtype: float64 16060    6.905111
# 60244    7.767072
# Name: time, dtype: float64 16060    0.0
# 60244    0.0
# Name: recycleTime, dtype: float64
# 60248    7.767072
# Name: time, dtype: float64 60248    7.767072
# Name: time, dtype: float64 60248    0.0
# Name: recycleTime, dtype: float64
# 60250     7.767072
# 133839    9.921974
# Name: time, dtype: float64 104416    9.060013
# 133839    9.921974
# Name: time, dtype: float64 104416    1.292941
# 133839    0.000000
# Name: recycleTime, dtype: float64
# 60251    7.767072
# Name: time, dtype: float64 60251    7.767072
# Name: time, dtype: float64 60251    0.0
# Name: recycleTime, dtype: float64
# 45538    7.336092
# Name: time, dtype: float64 60266    7.767072
# Name: time, dtype: float64 60266    0.43098
# Name: recycleTime, dtype: float64
# 16083    6.905111
# Name: time, dtype: float64 60267    7.767072
# Name: time, dtype: float64 60267    0.861961
# Name: recycleTime, dtype: float64
# 45540    7.336092
# 89716    8.608831
# Name: time, dtype: float64 60268    7.767072
# 89716    8.608831
# Name: time, dtype: float64 60268    0.43098
# 89716    0.00000
# Name: recycleTime, dtype: float64
# 30813    7.039793
# 60269    7.767072
# Name: time, dtype: float64 30813    7.039793
# 74996    8.198053
# Name: time, dtype: float64 30813    0.00000
# 74996    0.43098
# Name: recycleTime, dtype: float64
# 16086     6.905111
# 89718     8.608831
# 133859    9.921974
# Name: time, dtype: float64 30814      7.039793
# 89718      8.608831
# 148555    10.352954
# Name: time, dtype: float64 30814     0.134681
# 89718     0.000000
# 148555    0.430980
# Name: recycleTime, dtype: float64
# 16088    6.905111
# 45544    7.336092
# Name: time, dtype: float64 16088    6.905111
# 45544    7.336092
# Name: time, dtype: float64 16088    0.0
# 45544    0.0
# Name: recycleTime, dtype: float64
# 30817    7.039793
# Name: time, dtype: float64 45545    7.336092
# Name: time, dtype: float64 45545    0.296299
# Name: recycleTime, dtype: float64
# 45573     7.336092
# 104467    9.060013
# Name: time, dtype: float64 60301      7.767072
# 177764    10.783935
# Name: time, dtype: float64 60301     0.430980
# 177764    1.723922
# Name: recycleTime, dtype: float64
# 16123    6.905111
# Name: time, dtype: float64 16123    6.905111
# Name: time, dtype: float64 16123    0.0
# Name: recycleTime, dtype: float64
# 30860    7.039793
# 60316    7.767072
# Name: time, dtype: float64 30860    7.039793
# 60316    7.767072
# Name: time, dtype: float64 30860    0.0
# 60316    0.0
# Name: recycleTime, dtype: float64
# 16150    6.905111
# Name: time, dtype: float64 60334    7.767072
# Name: time, dtype: float64 60334    0.861961
# Name: recycleTime, dtype: float64
# 60337    7.767072
# Name: time, dtype: float64 60337    7.767072
# Name: time, dtype: float64 60337    0.0
# Name: recycleTime, dtype: float64
# 30882    7.039793
# Name: time, dtype: float64 30882    7.039793
# Name: time, dtype: float64 30882    0.0
# Name: recycleTime, dtype: float64
# 16157    6.905111
# 45613    7.336092
# 89789    8.608831
# Name: time, dtype: float64 16157    6.905111
# 60341    7.767072
# 89789    8.608831
# Name: time, dtype: float64 16157    0.00000
# 60341    0.43098
# 89789    0.00000
# Name: recycleTime, dtype: float64
# 16158    6.905111
# Name: time, dtype: float64 30886    7.039793
# Name: time, dtype: float64 30886    0.134681
# Name: recycleTime, dtype: float64
# 30894    7.039793
# Name: time, dtype: float64 89798    8.608831
# Name: time, dtype: float64 89798    1.569038
# Name: recycleTime, dtype: float64
# 16170    6.905111
# 89802    8.608831
# Name: time, dtype: float64 16170    6.905111
# 89802    8.608831
# Name: time, dtype: float64 16170    0.0
# 89802    0.0
# Name: recycleTime, dtype: float64
# 16172    6.905111
# Name: time, dtype: float64 30900    7.039793
# Name: time, dtype: float64 30900    0.134681
# Name: recycleTime, dtype: float64
#   9%|███▍                                   | 469/5276 [00:01<00:12, 370.80it/s]
# 119235    9.490994
# Name: time, dtype: float64 119235    9.490994
# Name: time, dtype: float64 119235    0.0
# Name: recycleTime, dtype: float64
# 45630    7.336092
# Name: time, dtype: float64 60358    7.767072
# Name: time, dtype: float64 60358    0.43098
# Name: recycleTime, dtype: float64
# 16177    6.905111
# Name: time, dtype: float64 45633    7.336092
# Name: time, dtype: float64 45633    0.43098
# Name: recycleTime, dtype: float64
# 16179    6.905111
# Name: time, dtype: float64 30907    7.039793
# Name: time, dtype: float64 30907    0.134681
# Name: recycleTime, dtype: float64
# 45643    7.336092
# Name: time, dtype: float64 89819    8.608831
# Name: time, dtype: float64 89819    1.272739
# Name: recycleTime, dtype: float64
# 16194    6.905111
# 45650    7.336092
# 89826    8.608831
# Name: time, dtype: float64 16194    6.905111
# 45650    7.336092
# 89826    8.608831
# Name: time, dtype: float64 16194    0.0
# 45650    0.0
# 89826    0.0
# Name: recycleTime, dtype: float64
# 104547    9.060013
# Name: time, dtype: float64 104547    9.060013
# Name: time, dtype: float64 104547    0.0
# Name: recycleTime, dtype: float64
# 16203    6.905111
# Name: time, dtype: float64 30931    7.039793
# Name: time, dtype: float64 30931    0.134681
# Name: recycleTime, dtype: float64
# 16207    6.905111
# 45663    7.336092
# Name: time, dtype: float64 16207    6.905111
# 45663    7.336092
# Name: time, dtype: float64 16207    0.0
# 45663    0.0
# Name: recycleTime, dtype: float64
# 16222    6.905111
# 60406    7.767072
# Name: time, dtype: float64 16222    6.905111
# 60406    7.767072
# Name: time, dtype: float64 16222    0.0
# 60406    0.0
# Name: recycleTime, dtype: float64
# 16226    6.905111
# 89858    8.608831
# Name: time, dtype: float64 16226    6.905111
# 89858    8.608831
# Name: time, dtype: float64 16226    0.0
# 89858    0.0
# Name: recycleTime, dtype: float64
# 104587    9.060013
# Name: time, dtype: float64 104587    9.060013
# Name: time, dtype: float64 104587    0.0
# Name: recycleTime, dtype: float64
# 60430    7.767072
# Name: time, dtype: float64 60430    7.767072
# Name: time, dtype: float64 60430    0.0
# Name: recycleTime, dtype: float64
# 30981      7.039793
# 75164      8.198053
# 119315     9.490994
# 192417    11.214915
# Name: time, dtype: float64 45709      7.336092
# 89885      8.608831
# 119315     9.490994
# 261912    12.938837
# Name: time, dtype: float64 45709     0.296299
# 89885     0.410778
# 119315    0.000000
# 261912    1.723922
# Name: recycleTime, dtype: float64
# 30982    7.039793
# 60438    7.767072
# 89886    8.608831
# Name: time, dtype: float64 30982    7.039793
# 60438    7.767072
# 89886    8.608831
# Name: time, dtype: float64 30982    0.0
# 60438    0.0
# 89886    0.0
# Name: recycleTime, dtype: float64
# 16255    6.905111
# Name: time, dtype: float64 60439    7.767072
# Name: time, dtype: float64 60439    0.861961
# Name: recycleTime, dtype: float64
# 16262    6.905111
# 45718    7.336092
# Name: time, dtype: float64 16262    6.905111
# 45718    7.336092
# Name: time, dtype: float64 16262    0.0
# 45718    0.0
# Name: recycleTime, dtype: float64
# 30997    7.039793
# Name: time, dtype: float64 30997    7.039793
# Name: time, dtype: float64 30997    0.0
# Name: recycleTime, dtype: float64
# 45729      7.336092
# 75184      8.198053
# 104623     9.060013
# 148739    10.352954
# Name: time, dtype: float64 45729      7.336092
# 75184      8.198053
# 104623     9.060013
# 148739    10.352954
# Name: time, dtype: float64 45729     0.0
# 75184     0.0
# 104623    0.0
# 148739    0.0
# Name: recycleTime, dtype: float64
# 16277    6.905111
# 75188    8.198053
# Name: time, dtype: float64 45733    7.336092
# 75188    8.198053
# Name: time, dtype: float64 45733    0.43098
# 75188    0.00000
# Name: recycleTime, dtype: float64
# 119341    9.490994
# Name: time, dtype: float64 119341    9.490994
# Name: time, dtype: float64 119341    0.0
# Name: recycleTime, dtype: float64
# 60465    7.767072
# Name: time, dtype: float64 60465    7.767072
# Name: time, dtype: float64 60465    0.0
# Name: recycleTime, dtype: float64
# 60470    7.767072
# Name: time, dtype: float64 75197    8.198053
# Name: time, dtype: float64 75197    0.43098
# Name: recycleTime, dtype: float64
# 16287    6.905111
# Name: time, dtype: float64 16287    6.905111
# Name: time, dtype: float64 16287    0.0
# Name: recycleTime, dtype: float64
# 31019     7.039793
# 134062    9.921974
# Name: time, dtype: float64 60475      7.767072
# 220875    12.076876
# Name: time, dtype: float64 60475     0.727279
# 220875    2.154902
# Name: recycleTime, dtype: float64
# 31032    7.039793
# Name: time, dtype: float64 31032    7.039793
# Name: time, dtype: float64 31032    0.0
# Name: recycleTime, dtype: float64
# 60503    7.767072
# Name: time, dtype: float64 177961    10.783935
# Name: time, dtype: float64 177961    3.016863
# Name: recycleTime, dtype: float64
# 60507    7.767072
# Name: time, dtype: float64 60507    7.767072
# Name: time, dtype: float64 60507    0.0
# Name: recycleTime, dtype: float64
# 31056    7.039793
# 60512    7.767072
# Name: time, dtype: float64 31056    7.039793
# 60512    7.767072
# Name: time, dtype: float64 31056    0.0
# 60512    0.0
# Name: recycleTime, dtype: float64
# 45787    7.336092
# Name: time, dtype: float64 45787    7.336092
# Name: time, dtype: float64 45787    0.0
# Name: recycleTime, dtype: float64
# 119393     9.490994
# 163436    10.767100
# Name: time, dtype: float64 134102     9.921974
# 177973    10.783935
# Name: time, dtype: float64 134102    0.430980
# 177973    0.016835
# Name: recycleTime, dtype: float64
# 60517    7.767072
# Name: time, dtype: float64 60517    7.767072
# Name: time, dtype: float64 60517    0.0
# Name: recycleTime, dtype: float64
# 119396    9.490994
# Name: time, dtype: float64 119396    9.490994
# Name: time, dtype: float64 119396    0.0
# Name: recycleTime, dtype: float64
# 45792    7.336092
# Name: time, dtype: float64 60520    7.767072
# Name: time, dtype: float64 60520    0.43098
# Name: recycleTime, dtype: float64
# 45793    7.336092
# Name: time, dtype: float64 60521    7.767072
# Name: time, dtype: float64 60521    0.43098
# Name: recycleTime, dtype: float64
# 31074    7.039793
# Name: time, dtype: float64 45802    7.336092
# Name: time, dtype: float64 45802    0.296299
# Name: recycleTime, dtype: float64
# 60538    7.767072
# Name: time, dtype: float64 60538    7.767072
# Name: time, dtype: float64 60538    0.0
# Name: recycleTime, dtype: float64
# 89988     8.608831
# 134127    9.921974
# Name: time, dtype: float64 89988     8.608831
# 134127    9.921974
# Name: time, dtype: float64 89988     0.0
# 134127    0.0
# Name: recycleTime, dtype: float64
# 60542    7.767072
# Name: time, dtype: float64 60542    7.767072
# Name: time, dtype: float64 60542    0.0
# Name: recycleTime, dtype: float64
# 60544    7.767072
# Name: time, dtype: float64 60544    7.767072
# Name: time, dtype: float64 60544    0.0
# Name: recycleTime, dtype: float64
# 16367    6.905111
# 45823    7.336092
# Name: time, dtype: float64 16367    6.905111
# 60551    7.767072
# Name: time, dtype: float64 16367    0.00000
# 60551    0.43098
# Name: recycleTime, dtype: float64
# 90003    8.608831
# Name: time, dtype: float64 90003    8.608831
# Name: time, dtype: float64 90003    0.0
# Name: recycleTime, dtype: float64
# 16380    6.905111
# Name: time, dtype: float64 16380    6.905111
# Name: time, dtype: float64 16380    0.0
# Name: recycleTime, dtype: float64
#  10%|████                                   | 546/5276 [00:01<00:12, 371.53it/s]
# 16389    6.905111
# Name: time, dtype: float64 16389    6.905111
# Name: time, dtype: float64 16389    0.0
# Name: recycleTime, dtype: float64
# 16400     6.905111
# 90031     8.608831
# 119461    9.490994
# Name: time, dtype: float64 31128     7.039793
# 90031     8.608831
# 119461    9.490994
# Name: time, dtype: float64 31128     0.134681
# 90031     0.000000
# 119461    0.000000
# Name: recycleTime, dtype: float64
# 16401    6.905111
# Name: time, dtype: float64 45857    7.336092
# Name: time, dtype: float64 45857    0.43098
# Name: recycleTime, dtype: float64
# 60591    7.767072
# Name: time, dtype: float64 75318    8.198053
# Name: time, dtype: float64 75318    0.43098
# Name: recycleTime, dtype: float64
# 104759    9.060013
# Name: time, dtype: float64 104759    9.060013
# Name: time, dtype: float64 104759    0.0
# Name: recycleTime, dtype: float64
# 60599    7.767072
# Name: time, dtype: float64 104764    9.060013
# Name: time, dtype: float64 104764    1.292941
# Name: recycleTime, dtype: float64
# 119484     9.490994
# 148888    10.352954
# Name: time, dtype: float64 119484     9.490994
# 178064    10.783935
# Name: time, dtype: float64 119484    0.00000
# 178064    0.43098
# Name: recycleTime, dtype: float64
# 31154      7.039793
# 90057      8.608831
# 248548    12.507856
# Name: time, dtype: float64 60610      7.767072
# 206926    11.645896
# 262070    12.938837
# Name: time, dtype: float64 60610     0.727279
# 206926    3.037065
# 262070    0.430980
# Name: recycleTime, dtype: float64
# 90058    8.608831
# Name: time, dtype: float64 90058    8.608831
# Name: time, dtype: float64 90058    0.0
# Name: recycleTime, dtype: float64
# 16431    6.905111
# Name: time, dtype: float64 16431    6.905111
# Name: time, dtype: float64 16431    0.0
# Name: recycleTime, dtype: float64
# 75358     8.198053
# 104796    9.060013
# Name: time, dtype: float64 75358     8.198053
# 104796    9.060013
# Name: time, dtype: float64 75358     0.0
# 104796    0.0
# Name: recycleTime, dtype: float64
# 90080     8.608831
# 134219    9.921974
# Name: time, dtype: float64 104798    9.060013
# 134219    9.921974
# Name: time, dtype: float64 104798    0.451183
# 134219    0.000000
# Name: recycleTime, dtype: float64
# 16456     6.905111
# 90087     8.608831
# 119517    9.490994
# Name: time, dtype: float64 60640     7.767072
# 90087     8.608831
# 119517    9.490994
# Name: time, dtype: float64 60640     0.861961
# 90087     0.000000
# ...
# Name: time, dtype: float64 72793      7.767072
# 175545    10.767100
# Name: time, dtype: float64 72793     0.430980
# 175545    2.158269
# Name: recycleTime, dtype: float64
# 87537    8.198053
# Name: time, dtype: float64 87537    8.198053
# Name: time, dtype: float64 87537    0.0
# Name: recycleTime, dtype: float64
# 146379    9.921974
# Name: time, dtype: float64 146379    9.921974
# Name: time, dtype: float64 146379    0.0
# Name: recycleTime, dtype: float64
# 87548     8.198053
# 131690    9.490994
# Name: time, dtype: float64 87548     8.198053
# 131690    9.490994
# Name: time, dtype: float64 87548     0.0
# 131690    0.0
# Name: recycleTime, dtype: float64
# 116985    9.060013
# Name: time, dtype: float64 190116    10.783935
# Name: time, dtype: float64 190116    1.723922
# Name: recycleTime, dtype: float64
# 58105    7.336092
# Name: time, dtype: float64 72833    7.767072
# Name: time, dtype: float64 72833    0.43098
# Name: recycleTime, dtype: float64
# 116999     9.060013
# 146408     9.921974
# 259779    12.507856
# Name: time, dtype: float64 116999     9.060013
# 218626    11.645896
# 273036    12.938837
# Name: time, dtype: float64 116999    0.000000
# 218626    1.723922
# 273036    0.430980
# Name: recycleTime, dtype: float64
# 161058    10.352954
# Name: time, dtype: float64 204500    11.214915
# Name: time, dtype: float64 204500    0.861961
# Name: recycleTime, dtype: float64
# 87583    8.198053
# Name: time, dtype: float64 102301    8.608831
# Name: time, dtype: float64 102301    0.410778
# Name: recycleTime, dtype: float64
# 131729    9.490994
# Name: time, dtype: float64 146428    9.921974
# Name: time, dtype: float64 146428    0.43098
# Name: recycleTime, dtype: float64
# 28709    6.905111
# Name: time, dtype: float64 58165    7.336092
# Name: time, dtype: float64 58165    0.43098
# Name: recycleTime, dtype: float64
# 117056    9.060013
# Name: time, dtype: float64 117056    9.060013
# Name: time, dtype: float64 117056    0.0
# Name: recycleTime, dtype: float64
# 117058    9.060013
# 146467    9.921974
# Name: time, dtype: float64 117058    9.060013
# 146467    9.921974
# Name: time, dtype: float64 117058    0.0
# 146467    0.0
# Name: recycleTime, dtype: float64
# 28724    6.905111
# Name: time, dtype: float64 43452    7.039793
# Name: time, dtype: float64 43452    0.134681
# Name: recycleTime, dtype: float64
# 28726    6.905111
# 72910    7.767072
# Name: time, dtype: float64 43454    7.039793
# 87631    8.198053
# Name: time, dtype: float64 43454    0.134681
# 87631    0.430980
# Name: recycleTime, dtype: float64
# 87636    8.198053
# Name: time, dtype: float64 87636    8.198053
# Name: time, dtype: float64 87636    0.0
# Name: recycleTime, dtype: float64
# 72923     7.767072
# 117076    9.060013
# Name: time, dtype: float64 72923     7.767072
# 131786    9.490994
# Name: time, dtype: float64 72923     0.00000
# 131786    0.43098
# Name: recycleTime, dtype: float64
# 102374    8.608831
# Name: time, dtype: float64 146497    9.921974
# Name: time, dtype: float64 146497    1.313143
# Name: recycleTime, dtype: float64
# 102386     8.608831
# 131810     9.490994
# 218720    11.645896
# Name: time, dtype: float64 102386     8.608831
# 190231    10.783935
# 232540    12.076876
# Name: time, dtype: float64 102386    0.000000
# 190231    1.292941
# 232540    0.430980
# Name: recycleTime, dtype: float64
# 28767     6.905111
# 102390    8.608831
# 131814    9.490994
# Name: time, dtype: float64 43495     7.039793
# 102390    8.608831
# 131814    9.490994
# Name: time, dtype: float64 43495     0.134681
# 102390    0.000000
# 131814    0.000000
# Name: recycleTime, dtype: float64
# 28772    6.905111
# Name: time, dtype: float64 43500    7.039793
# Name: time, dtype: float64 43500    0.134681
# Name: recycleTime, dtype: float64
# 87682    8.198053
# Name: time, dtype: float64 87682    8.198053
# Name: time, dtype: float64 87682    0.0
# Name: recycleTime, dtype: float64
# 102404    8.608831
# 146527    9.921974
# Name: time, dtype: float64 117118     9.060013
# 246324    12.150951
# Name: time, dtype: float64 117118    0.451183
# 246324    2.228977
# Name: recycleTime, dtype: float64
# 102418    8.608831
# Name: time, dtype: float64 102418    8.608831
# Name: time, dtype: float64 102418    0.0
# Name: recycleTime, dtype: float64
# 58252    7.336092
# Name: time, dtype: float64 58252    7.336092
# Name: time, dtype: float64 58252    0.0
# Name: recycleTime, dtype: float64
#  98%|█████████████████████████████████████▏| 5168/5276 [00:13<00:00, 434.72it/s]
# 102423    8.608831
# Name: time, dtype: float64 102423    8.608831
# Name: time, dtype: float64 102423    0.0
# Name: recycleTime, dtype: float64
# 131856    9.490994
# Name: time, dtype: float64 131856    9.490994
# Name: time, dtype: float64 131856    0.0
# Name: recycleTime, dtype: float64
# 102454    8.608831
# 131878    9.490994
# Name: time, dtype: float64 102454    8.608831
# 146577    9.921974
# Name: time, dtype: float64 102454    0.00000
# 146577    0.43098
# Name: recycleTime, dtype: float64
# 43678    7.039793
# Name: time, dtype: float64 43678    7.039793
# Name: time, dtype: float64 43678    0.0
# Name: recycleTime, dtype: float64
# 102605     8.608831
# 175917    10.767100
# 218934    11.645896
# Name: time, dtype: float64 117319     9.060013
# 190450    10.783935
# 273332    12.938837
# Name: time, dtype: float64 117319    0.451183
# 190450    0.016835
# 273332    1.292941
# Name: recycleTime, dtype: float64
# 28995    6.905111
# 73179    7.767072
# Name: time, dtype: float64 43723    7.039793
# 73179    7.767072
# Name: time, dtype: float64 43723    0.134681
# 73179    0.000000
# Name: recycleTime, dtype: float64
# 175954    10.7671
# Name: time, dtype: float64 218971    11.645896
# Name: time, dtype: float64 218971    0.878796
# Name: recycleTime, dtype: float64
# 43749    7.039793
# Name: time, dtype: float64 43749    7.039793
# Name: time, dtype: float64 43749    0.0
# Name: recycleTime, dtype: float64
# 73206     7.767072
# 117359    9.060013
# Name: time, dtype: float64 87927      8.198053
# 204858    11.214915
# Name: time, dtype: float64 87927     0.430980
# 204858    2.154902
# Name: recycleTime, dtype: float64
# 87940      8.198053
# 146781     9.921974
# 175970    10.767100
# Name: time, dtype: float64 87940      8.198053
# 146781     9.921974
# 232806    12.076876
# Name: time, dtype: float64 87940     0.000000
# 146781    0.000000
# 232806    1.309776
# Name: recycleTime, dtype: float64
# 132099    9.490994
# Name: time, dtype: float64 161447    10.352954
# Name: time, dtype: float64 161447    0.861961
# Name: recycleTime, dtype: float64
# 87976    8.198053
# Name: time, dtype: float64 87976    8.198053
# Name: time, dtype: float64 87976    0.0
# Name: recycleTime, dtype: float64
# 43856    7.039793
# Name: time, dtype: float64 43856    7.039793
# Name: time, dtype: float64 43856    0.0
# Name: recycleTime, dtype: float64
# 73314    7.767072
# Name: time, dtype: float64 88035    8.198053
# Name: time, dtype: float64 88035    0.43098
# Name: recycleTime, dtype: float64
# 43861    7.039793
# 73317    7.767072
# Name: time, dtype: float64 43861    7.039793
# 73317    7.767072
# Name: time, dtype: float64 43861    0.0
# 73317    0.0
# Name: recycleTime, dtype: float64
# 58591    7.336092
# Name: time, dtype: float64 58591    7.336092
# Name: time, dtype: float64 58591    0.0
# Name: recycleTime, dtype: float64
# 88041    8.198053
# Name: time, dtype: float64 117473    9.060013
# Name: time, dtype: float64 117473    0.861961
# Name: recycleTime, dtype: float64
# 58593    7.336092
# Name: time, dtype: float64 58593    7.336092
# Name: time, dtype: float64 58593    0.0
# Name: recycleTime, dtype: float64
# 29141    6.905111
# Name: time, dtype: float64 58597    7.336092
# Name: time, dtype: float64 58597    0.43098
# Name: recycleTime, dtype: float64
# 29147    6.905111
# Name: time, dtype: float64 43875    7.039793
# Name: time, dtype: float64 43875    0.134681
# Name: recycleTime, dtype: float64
# 29149     6.905111
# 73333     7.767072
# 102772    8.608831
# Name: time, dtype: float64 43877     7.039793
# 73333     7.767072
# 102772    8.608831
# Name: time, dtype: float64 43877     0.134681
# 73333     0.000000
# 102772    0.000000
# Name: recycleTime, dtype: float64
# 58608    7.336092
# Name: time, dtype: float64 58608    7.336092
# Name: time, dtype: float64 58608    0.0
# Name: recycleTime, dtype: float64
# 88058      8.198053
# 161547    10.352954
# Name: time, dtype: float64 88058      8.198053
# 219103    11.645896
# Name: time, dtype: float64 88058     0.000000
# 219103    1.292941
# Name: recycleTime, dtype: float64
# 73340    7.767072
# Name: time, dtype: float64 73340    7.767072
# Name: time, dtype: float64 73340    0.0
# Name: recycleTime, dtype: float64
# 117494    9.060013
# Name: time, dtype: float64 132204    9.490994
# Name: time, dtype: float64 132204    0.43098
# Name: recycleTime, dtype: float64
# 29160    6.905111
# Name: time, dtype: float64 43888    7.039793
# Name: time, dtype: float64 43888    0.134681
# Name: recycleTime, dtype: float64
# 117500    9.060013
# Name: time, dtype: float64 132210    9.490994
# Name: time, dtype: float64 132210    0.43098
# Name: recycleTime, dtype: float64
# 29168    6.905111
# Name: time, dtype: float64 58624    7.336092
# Name: time, dtype: float64 58624    0.43098
# Name: recycleTime, dtype: float64
# 43898    7.039793
# Name: time, dtype: float64 58626    7.336092
# Name: time, dtype: float64 58626    0.296299
# Name: recycleTime, dtype: float64
# 29178    6.905111
# Name: time, dtype: float64 29178    6.905111
# Name: time, dtype: float64 29178    0.0
# Name: recycleTime, dtype: float64
# 102807     8.608831
# 176116    10.767100
# Name: time, dtype: float64 146930     9.921974
# 205016    11.214915
# Name: time, dtype: float64 146930    1.313143
# 205016    0.447816
# Name: recycleTime, dtype: float64
# 43914    7.039793
# Name: time, dtype: float64 43914    7.039793
# Name: time, dtype: float64 43914    0.0
# Name: recycleTime, dtype: float64
# 29202    6.905111
# Name: time, dtype: float64 29202    6.905111
# Name: time, dtype: float64 29202    0.0
# Name: recycleTime, dtype: float64
# 73393    7.767072
# Name: time, dtype: float64 88114    8.198053
# Name: time, dtype: float64 88114    0.43098
# Name: recycleTime, dtype: float64
# 43941    7.039793
# Name: time, dtype: float64 43941    7.039793
# Name: time, dtype: float64 43941    0.0
# Name: recycleTime, dtype: float64
# 29214    6.905111
# Name: time, dtype: float64 29214    6.905111
# Name: time, dtype: float64 29214    0.0
# Name: recycleTime, dtype: float64
# 73399    7.767072
# Name: time, dtype: float64 73399    7.767072
# Name: time, dtype: float64 73399    0.0
# Name: recycleTime, dtype: float64
# 58672    7.336092
# Name: time, dtype: float64 58672    7.336092
# Name: time, dtype: float64 58672    0.0
# Name: recycleTime, dtype: float64
# 43952    7.039793
# Name: time, dtype: float64 43952    7.039793
# Name: time, dtype: float64 43952    0.0
# Name: recycleTime, dtype: float64
# 58682    7.336092
# Name: time, dtype: float64 88131    8.198053
# Name: time, dtype: float64 88131    0.861961
# Name: recycleTime, dtype: float64
# 100%|██████████████████████████████████████| 5276/5276 [00:13<00:00, 378.72it/s]
# 43961      7.039793
# 88138      8.198053
# 117570     9.060013
# 176165    10.767100
# Name: time, dtype: float64 43961      7.039793
# 88138      8.198053
# 132280     9.490994
# 219178    11.645896
# Name: time, dtype: float64 43961     0.000000
# 88138     0.000000
# 132280    0.430980
# 219178    0.878796
# Name: recycleTime, dtype: float64
# 43962     7.039793
# 73418     7.767072
# 102857    8.608831
# Name: time, dtype: float64 43962     7.039793
# 73418     7.767072
# 102857    8.608831
# Name: time, dtype: float64 43962     0.0
# 73418     0.0
# 102857    0.0
# Name: recycleTime, dtype: float64
# 43970     7.039793
# 73426     7.767072
# 102865    8.608831
# Name: time, dtype: float64 43970     7.039793
# 73426     7.767072
# 146988    9.921974
# Name: time, dtype: float64 43970     0.000000
# 73426     0.000000
# 146988    1.313143
# Name: recycleTime, dtype: float64
# 73439    7.767072
# Name: time, dtype: float64 73439    7.767072
# Name: time, dtype: float64 73439    0.0
# Name: recycleTime, dtype: float64
# 88174    8.198053
# Name: time, dtype: float64 88174    8.198053
# Name: time, dtype: float64 88174    0.0
# Name: recycleTime, dtype: float64
# 58727    7.336092
# Name: time, dtype: float64 58727    7.336092
# Name: time, dtype: float64 58727    0.0
# Name: recycleTime, dtype: float64
# 29272    6.905111
# Name: time, dtype: float64 44000    7.039793
# Name: time, dtype: float64 44000    0.134681
# Name: recycleTime, dtype: float64
# 29275    6.905111
# Name: time, dtype: float64 44003    7.039793
# Name: time, dtype: float64 44003    0.134681
# Name: recycleTime, dtype: float64
# 117628    9.060013
# 147037    9.921974
# Name: time, dtype: float64 117628     9.060013
# 161685    10.352954
# Name: time, dtype: float64 117628    0.00000
# 161685    0.43098
# Name: recycleTime, dtype: float64
# 88211     8.198053
# 117643    9.060013
# 147052    9.921974
# Name: time, dtype: float64 88211     8.198053
# 117643    9.060013
# 147052    9.921974
# Name: time, dtype: float64 88211     0.0
# 117643    0.0
# 147052    0.0
# Name: recycleTime, dtype: float64
# 102941    8.608831
# Name: time, dtype: float64 132365    9.490994
# Name: time, dtype: float64 132365    0.882163
# Name: recycleTime, dtype: float64
# 44047    7.039793
# Name: time, dtype: float64 58775    7.336092
# Name: time, dtype: float64 58775    0.296299
# Name: recycleTime, dtype: float64
# 58779    7.336092
# Name: time, dtype: float64 73507    7.767072
# Name: time, dtype: float64 73507    0.43098
# Name: recycleTime, dtype: float64
# 58785    7.336092
# Name: time, dtype: float64 58785    7.336092
# Name: time, dtype: float64 58785    0.0
# Name: recycleTime, dtype: float64
# 44061    7.039793
# 73517    7.767072
# Name: time, dtype: float64 44061    7.039793
# 73517    7.767072
# Name: time, dtype: float64 44061    0.0
# 73517    0.0
# Name: recycleTime, dtype: float64
# 58793    7.336092
# Name: time, dtype: float64 73521    7.767072
# Name: time, dtype: float64 73521    0.43098
# Name: recycleTime, dtype: float64
# 102965     8.608831
# 161735    10.352954
# 219283    11.645896
# Name: time, dtype: float64 102965     8.608831
# 190806    10.783935
# 219283    11.645896
# Name: time, dtype: float64 102965    0.00000
# 190806    0.43098
# 219283    0.00000
# Name: recycleTime, dtype: float64
# 29350    6.905111
# Name: time, dtype: float64 44078    7.039793
# Name: time, dtype: float64 44078    0.134681
# Name: recycleTime, dtype: float64
# 102976    8.608831
# 147099    9.921974
# Name: time, dtype: float64 102976     8.608831
# 161746    10.352954
# Name: time, dtype: float64 102976    0.00000
# 161746    0.43098
# Name: recycleTime, dtype: float64
# 132405    9.490994
# Name: time, dtype: float64 132405    9.490994
# Name: time, dtype: float64 132405    0.0
# Name: recycleTime, dtype: float64
# 73545    7.767072
# Name: time, dtype: float64 73545    7.767072
# Name: time, dtype: float64 73545    0.0
# Name: recycleTime, dtype: float64
# 29373    6.905111
# Name: time, dtype: float64 44101    7.039793
# Name: time, dtype: float64 44101    0.134681
# Name: recycleTime, dtype: float64
# 29388    6.905111
# Name: time, dtype: float64 58844    7.336092
# Name: time, dtype: float64 58844    0.43098
# Name: recycleTime, dtype: float64
# 29393    6.905111
# 58849    7.336092
# Name: time, dtype: float64 29393    6.905111
# 58849    7.336092
# Name: time, dtype: float64 29393    0.0
# 58849    0.0
# Name: recycleTime, dtype: float64
# 58851    7.336092
# Name: time, dtype: float64 58851    7.336092
# Name: time, dtype: float64 58851    0.0
# Name: recycleTime, dtype: float64
# 132446    9.490994
# Name: time, dtype: float64 147145    9.921974
# Name: time, dtype: float64 147145    0.43098
# Name: recycleTime, dtype: float64
# 88307    8.198053
# Name: time, dtype: float64 161795    10.352954
# Name: time, dtype: float64 161795    2.154902
# Name: recycleTime, dtype: float64
# 103031    8.608831
# Name: time, dtype: float64 103031    8.608831
# Name: time, dtype: float64 103031    0.0
# Name: recycleTime, dtype: float64
# 88322      8.198053
# 117754     9.060013
# 176347    10.767100
# Name: time, dtype: float64 88322      8.198053
# 117754     9.060013
# 219356    11.645896
# Name: time, dtype: float64 88322     0.000000
# 117754    0.000000
# 219356    0.878796
# Name: recycleTime, dtype: float64
# 29422    6.905111
# Name: time, dtype: float64 58878    7.336092
# Name: time, dtype: float64 58878    0.43098
# Name: recycleTime, dtype: float64
# 117773    9.060013
# Name: time, dtype: float64 117773    9.060013
# Name: time, dtype: float64 117773    0.0
# Name: recycleTime, dtype: float64

# %%
len(accreted)-len(adv_accreted)
# Out:
# 2367

# %% [markdown]
# So we immediately see by this first condition on the *accreted* set that we remove a good number of particles not corresponding to a discharge event.

# %%
from accretion import *

def read_accreted():
    adv_accreted = pd.DataFrame()

    keys = get_keys()

    for i,key in enumerate(keys):
        i += 1
        sim = key[:4]
        haloid = int(key[5:])
        adv_accreted1 = pd.read_hdf('/home/lonzaric/astro_research/Stellar_Feedback_Code/SNeData/adv_accreted.hdf5',\
             key=key)
        adv_accreted1['key'] = key
        adv_accreted = pd.concat([adv_accreted, adv_accreted1])


    print(f'> Returning (adv. accreted) for all available satellites <')
    return adv_accreted

# %%
adv_accreted = read_accreted()
# Out:
# h148_13 h148_278 h148_28 h148_283 h148_329 h148_37 h148_45 h148_68 h148_80 h229_20 h229_22 h229_23 h229_27 h229_55 h242_24 h242_41 h242_80 h329_137 h329_33
# > Returning (adv. accreted) for all available satellites <

# %%
adv_accreted
# Out:
#              time      pid       rho           temp          mass  coolontime  \
# 205282  11.645896  2202002  0.002334   14873.835938  28366.657652   10.908183
# 161854  10.767100  4073949  0.058975    9752.045898  26835.758536    0.000000
# 161858  10.767100  4340176  0.057253    9207.494141  27066.785805   10.685118
# 219418  12.076876  6936050  0.076830    8806.372070  27651.989951   11.744889
# 233230  12.150951  6988228  0.000113  170371.390625  26850.013274   11.038656
# ...           ...      ...       ...            ...           ...         ...
# 26198    8.608831  6627712  0.033717   12044.281250  26635.610201    4.748210
# 21829    8.413543  6627722  0.024180   12440.765625  26519.316821    0.000000
# 8719     7.443837  6627756  0.066316   11737.336914  26526.461460    0.000000
# 26208    8.608831  6627757  0.014028   13289.551758  26584.661687    0.000000
# 26221    8.608831  6630131  0.009136   13530.549805  26557.834319    0.000000
#
#                r  r_per_Rvir         x         y  ...  host_r_gal  sat_disk  \
# 205282  2.917399    0.051277 -1.943967 -1.597916  ...   21.516602     False
# 161854  0.849211    0.015786 -0.681446 -0.438338  ...   20.143633     False
# 161858  0.846655    0.015738 -0.573782 -0.505544  ...   20.143633     False
# 219418  0.534446    0.009112  0.530554  0.043023  ...   18.811293     False
# 233230  5.612292    0.095189  4.317860  2.915293  ...   20.529471     False
# ...          ...         ...       ...       ...  ...         ...       ...
# 26198   1.267604    0.110037 -0.912659 -0.696403  ...    9.596679     False
# 21829   1.900877    0.063894 -1.505597 -0.240243  ...   10.988910     False
# 8719    1.097153    0.040304  0.885839  0.543622  ...   12.407557     False
# 26208   2.624332    0.227811 -1.626817  1.831154  ...    9.596679     False
# 26221   2.374860    0.206155 -1.557276  0.816604  ...    9.596679     False
#
#         sat_halo  host_disk  host_halo  other_sat    IGM          t  \
# 205282      True      False      False      False  False  11.645896
# 161854      True      False      False      False  False  10.767100
# 161858      True      False      False      False  False  10.767100
# 219418      True      False      False      False  False  12.076876
# 233230     False      False      False      False   True  12.150951
# ...          ...        ...        ...        ...    ...        ...
# 26198       True      False      False      False  False   8.608831
# 21829       True      False      False      False  False   8.413543
# 8719        True      False      False      False  False   7.443837
# 26208       True      False      False      False  False   8.608831
# 26221       True      False      False      False  False   8.608831
#
#             sat_Mvir      key
# 205282  9.672413e+09  h148_13
# 161854  1.002284e+10  h148_13
# 161858  1.002284e+10  h148_13
# 219418  9.621392e+09  h148_13
# 233230  9.613553e+09  h148_13
# ...              ...      ...
# 26198   1.604989e+09  h329_33
# 21829   3.091517e+09  h329_33
# 8719    3.140099e+09  h329_33
# 26208   1.604989e+09  h329_33
# 26221   1.604989e+09  h329_33
#
# [116630 rows x 63 columns]
